# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import seaborn as sea
import matplotlib.pyplot as plt

# %%
dataFrame = pd.read_csv(r'C:\Users\prana\DataspellProjects\05101334-Data-Science\Datasets\vgsales.csv')
dataFrame
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
plt.scatter(x=dataFrame['EU_Sales'], y=dataFrame['NA_Sales'], c='#FFAA00')

# %%
dataFrame.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
dataFrame.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
# Out:
#         Rank Platform    Year         Genre   Publisher  NA_Sales  EU_Sales  \
# 0          1      Wii  2006.0        Sports    Nintendo     41.49     29.02
# 1          2      NES  1985.0      Platform    Nintendo     29.08      3.58
# 2          3      Wii  2008.0        Racing    Nintendo     15.85     12.88
# 3          4      Wii  2009.0        Sports    Nintendo     15.75     11.01
# 4          5       GB  1996.0  Role-Playing    Nintendo     11.27      8.89
# ...      ...      ...     ...           ...         ...       ...       ...
# 16593  16596      GBA  2002.0      Platform       Kemco      0.01      0.00
# 16594  16597       GC  2003.0       Shooter  Infogrames      0.01      0.00
# 16595  16598      PS2  2008.0        Racing  Activision      0.00      0.00
# 16596  16599       DS  2010.0        Puzzle    7G//AMES      0.00      0.01
# 16597  16600      GBA  2003.0      Platform     Wanadoo      0.01      0.00
#
#        JP_Sales  Other_Sales  Global_Sales
# ...

# %%
dataFrame = pd.read_csv(r'C:\Users\prana\DataspellProjects\05101334-Data-Science\Datasets\Walmart_Sales.csv')
dataFrame
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
dataFrame.dropna()
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
plt.scatter(x=dataFrame['Fuel_Price'], y=dataFrame['Temperature'], c='#EE00FF')
